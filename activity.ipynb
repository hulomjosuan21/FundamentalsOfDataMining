# %%
import pandas as pd

# %%
heart_df = pd.read_csv('heart.csv').sort_values(by='Cholesterol', ascending=False).head(150)
heart_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
# 76    32   M           ASY        118          529          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# 250   44   M           ASY        135          491          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 175   43   M           ASY        140          288          0     Normal
# 211   50   F           NAP        140          288          0     Normal
# 592   61   M           ASY        190          287          1        LVH
# 177   59   M           ATA        140          287          0     Normal
# 884   67   M           ASY        160          286          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart_df['Sex'] = [1 if x == 'M' else 0 for x in heart_df['Sex']]
heart_df
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54    1           ASY        130          603          1     Normal
# 616   67    0           NAP        115          564          0        LVH
# 76    32    1           ASY        118          529          0     Normal
# 30    53    1           NAP        145          518          0     Normal
# 250   44    1           ASY        135          491          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 175   43    1           ASY        140          288          0     Normal
# 211   50    0           NAP        140          288          0     Normal
# 592   61    1           ASY        190          287          1        LVH
# 177   59    1           ATA        140          287          0     Normal
# 884   67    1           ASY        160          286          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart_df
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54    1           ASY        130          603          1     Normal
# 616   67    0           NAP        115          564          0        LVH
# 76    32    1           ASY        118          529          0     Normal
# 30    53    1           NAP        145          518          0     Normal
# 250   44    1           ASY        135          491          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 175   43    1           ASY        140          288          0     Normal
# 211   50    0           NAP        140          288          0     Normal
# 592   61    1           ASY        190          287          1        LVH
# 177   59    1           ATA        140          287          0     Normal
# 884   67    1           ASY        160          286          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
new_heart_df = heart_df[['Age','Sex','ChestPainType','FastingBS','RestingECG','ExerciseAngina','ST_Slope','HeartDisease']]
new_heart_df
# Out:
#      Age  Sex ChestPainType  FastingBS RestingECG ExerciseAngina ST_Slope  \
# 149   54    1           ASY          1     Normal              Y     Flat
# 616   67    0           NAP          0        LVH              N     Flat
# 76    32    1           ASY          0     Normal              N     Flat
# 30    53    1           NAP          0     Normal              N     Flat
# 250   44    1           ASY          0     Normal              N     Flat
# ..   ...  ...           ...        ...        ...            ...      ...
# 175   43    1           ASY          0     Normal              Y     Flat
# 211   50    0           NAP          0     Normal              Y     Flat
# 592   61    1           ASY          1        LVH              Y     Down
# 177   59    1           ATA          0     Normal              N       Up
# 884   67    1           ASY          0        LVH              Y     Flat
#
#      HeartDisease
# 149             1
# 616             0
# 76              1
# ...

# %%
new_heart_df.to_csv('HulomJosuanLeonardo.csv', index=False)
