# %%
import pandas as pd

# %%
heart_df = pd.read_csv('heart.csv');

# %%
heart_df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# nSex                2
# dtype: int64

# %%
heart_df['nSex'] = [1 if x == 'M' else 0 for x in heart_df['Sex']]
heart_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  nSex
# 0              N      0.0       Up             0     1
# 1              N      1.0     Flat             1     0
# 2              N      0.0       Up             0     1
# 3              Y      1.5     Flat             1     0
# 4              N      0.0       Up             0     1

# %%
heart_df = heart_df.sort_values(by='Age', ascending=False)
heart_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 447   77   M           ASY        124          171          0         ST
# 814   77   M           ASY        125          304          0        LVH
# 688   76   F           NAP        140          197          0         ST
# 541   76   M           NAP        104          113          0        LVH
# 556   75   M           ASY        160          310          1     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 215   30   F            TA        170          237          0         ST
# 219   29   M           ATA        140          263          0     Normal
# 170   29   M           ATA        120          243          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 208   28   M           ATA        130          132          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  nSex
# ...

# %%
new_heart_df = heart_df[['Age','nSex','Cholesterol']]
new_heart_df
# Out:
#      Age  nSex  Cholesterol
# 447   77     1          171
# 814   77     1          304
# 688   76     0          197
# 541   76     1          113
# 556   75     1          310
# ..   ...   ...          ...
# 215   30     0          237
# 219   29     1          263
# 170   29     1          243
# 829   29     1          204
# 208   28     1          132
#
# [918 rows x 3 columns]

# %%
heart_df['nSex'] = [1 if x == 'M' else 0 for x in heart_df['Sex']]
heart_df.head()
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 447   77    0           ASY        124          171          0         ST
# 814   77    0           ASY        125          304          0        LVH
# 688   76    0           NAP        140          197          0         ST
# 541   76    0           NAP        104          113          0        LVH
# 556   75    0           ASY        160          310          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  nSex
# 447    110              Y      2.0       Up             1     0
# 814    162              Y      0.0       Up             1     0
# 688    116              N      1.1     Flat             0     0
# 541    120              N      3.5     Down             1     0
# 556    112              Y      2.0     Down             0     0
